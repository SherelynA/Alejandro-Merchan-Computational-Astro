# %%
from INTI.main import call_inti

# %%
species = 'C2H2'             # Chemical species name        

call_inti(species = species,isotopologue=1)    # If you don't specify a line list name, a default line list will be downloaded
# Out:
# Validating user provided inputs...
#
# Fetching data from HITRAN. This could take up to an hour so do not stop the download.
# Molecule: C2H2
# Isotopologue (12C)2H2
#
# 26 1
# Using ./input/C2H2  ~  (12C2-1H2)/HITRAN/
#
#
# Data is fetched from http://hitran.org
#
# BEGIN DOWNLOAD: C2H2
#   65536 bytes written to ./input/C2H2  ~  (12C2-1H2)/HITRAN//C2H2.data
#   65536 bytes written to ./input/C2H2  ~  (12C2-1H2)/HITRAN//C2H2.data
#   65536 bytes written to ./input/C2H2  ~  (12C2-1H2)/HITRAN//C2H2.data
#   65536 bytes written to ./input/C2H2  ~  (12C2-1H2)/HITRAN//C2H2.data
#   65536 bytes written to ./input/C2H2  ~  (12C2-1H2)/HITRAN//C2H2.data
#   65536 bytes written to ./input/C2H2  ~  (12C2-1H2)/HITRAN//C2H2.data
#   65536 bytes written to ./input/C2H2  ~  (12C2-1H2)/HITRAN//C2H2.data
#   65536 bytes written to ./input/C2H2  ~  (12C2-1H2)/HITRAN//C2H2.data
#   65536 bytes written to ./input/C2H2  ~  (12C2-1H2)/HITRAN//C2H2.data
# ...

# %%
from INTI.main import calculate_inti

P = 1                          # Pressure in bar
T = 400                       # Temperature in Kelvin
input_directory = './input/'   # Directory containing the line lists

# Calculate the CO cross section
calculate_inti(species = species,
                      temperature = T, pressure = P,
                      input_dir = input_directory,     # Compute cross section has many more optional arguments and settings
                      )
